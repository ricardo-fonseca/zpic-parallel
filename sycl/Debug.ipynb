# %% [markdown]
# # Visualizing ZDF files

# %% [markdown]
# ### Scalar field grid test

# %%
import visxd

#visxd.plot_data("sycl/sycl",0)

# %% [markdown]
# ### Vector field grid test

# %%
import visxd

#visxd.plot_data("sycl/sycl",0)
visxd.plot_data("sycl/sycl-vec3-x",0 )
visxd.plot_data("sycl/sycl-vec3-y",0 )
visxd.plot_data("sycl/sycl-vec3-z",0 )
# Out:
# Plotting sycl/sycl-vec3-x-000000.zdf
# Plotting sycl/sycl-vec3-y-000000.zdf
# Plotting sycl/sycl-vec3-z-000000.zdf

# %% [markdown]
# ### Laser test
#
# Injects a laser pulse and propagates it.

# %%
import visxd

iter = 731

visxd.plot_data("EMF/Ex", iter )
visxd.plot_data("EMF/Ey", iter )
visxd.plot_data("EMF/Ez", iter )
# Out:
# Plotting EMF/Ex-000731.zdf
# Plotting EMF/Ey-000731.zdf
# Plotting EMF/Ez-000731.zdf

# %% [markdown]
# ### Injection test
#
# Sets a density profile and injects it.

# %%
import visxd

visxd.plot_data("CHARGE/electrons/electrons-charge", 0, vmin = -2 )
visxd.plot_part("PARTICLES/electrons/particles-electrons", 0 )
visxd.plot_data("PHASESPACE/electrons/electrons-uxuz", 0)
# Out:
# Plotting CHARGE/electrons/electrons-charge-000000.zdf
# Plotting PARTICLES/electrons/particles-electrons-000000.zdf
# Plotting PHASESPACE/electrons/electrons-uxuz-000000.zdf

# %% [markdown]
# ### Motion test
#
# Injects a sphere density and moves it for _N_ timesteps. This is performed outside of the simulation, no current is deposited.

# %%
import visxd

# Initial density
visxd.plot_data("CHARGE/electrons/electrons-charge", 0 )

# Final density and particles
iter = 100
visxd.plot_data("CHARGE/electrons/electrons-charge", iter )
visxd.plot_part("PARTICLES/electrons/particles-electrons", iter )
# Out:
# Plotting CHARGE/electrons/electrons-charge-000000.zdf
# Plotting CHARGE/electrons/electrons-charge-000100.zdf
# Plotting PARTICLES/electrons/particles-electrons-000100.zdf

# %% [markdown]
# ### Current deposit test
#
# Runs 1 iteration of the motion test above and deposits current

# %%
import visxd

iter = 1

visxd.plot_data("CURRENT/Jx", iter )
visxd.plot_data("CURRENT/Jy", iter )
visxd.plot_data("CURRENT/Jz", iter )
# Out:
# Plotting CURRENT/Jx-000001.zdf
# Plotting CURRENT/Jy-000001.zdf
# Plotting CURRENT/Jz-000001.zdf
