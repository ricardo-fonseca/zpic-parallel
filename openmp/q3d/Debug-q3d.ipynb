# %% [markdown]
# # Debug OpenMP Q3D code
#
# Q3D code tests

# %% [markdown]
# ## Laser test
#
# `test_laser()`

# %%
import visxd
import matplotlib.colors as colors

import importlib
importlib.reload( visxd )

def fname( comp, iter ):
    return "EMF/{:s}-{:06d}.zdf".format( comp, iter )

! ls EMF/*.zdf

iter = 100
# iter = 731

# visxd.complex_grid2d(fname("B1z", iter), part = 'abs' )
# visxd.complex_grid2d(fname("B1r", iter), part = 'abs' )
# visxd.complex_grid2d(fname("B1θ", iter), part = 'abs' )


visxd.complex_grid2d(fname("E1z", iter), part = 'abs', ylim = [0,10], vmax = 0.5 )
visxd.complex_grid2d(fname("E1r", iter), part = 'abs' )
visxd.complex_grid2d(fname("E1θ", iter), part = 'abs' )

# visxd.complex_grid2d(fname("E1θ", 0), part = 'real' )
# visxd.complex_grid2d(fname("E1r", 0), part = 'imag' )

# visxd.complex_grid2d(fname("E1z", 0), part = 'abs', ylim = [0,10])
# visxd.complex_grid2d(fname("B1z", 0), part = 'abs', ylim = [-1,1], xlim = [-1, 22])
# Out:
# EMF/B1r-000000.zdf  EMF/B1z-000100.zdf  EMF/E1r-000000.zdf  EMF/E1z-000100.zdf
# EMF/B1r-000100.zdf  EMF/B1θ-000000.zdf  EMF/E1r-000100.zdf  EMF/E1θ-000000.zdf
# EMF/B1z-000000.zdf  EMF/B1θ-000100.zdf  EMF/E1z-000000.zdf  EMF/E1θ-000100.zdf

# %% [markdown]
# ## Weibel test
#
# `test_weibel()`

# %%
import visxd
import matplotlib.colors as colors

# iter = 0
iter = 500

visxd.plot_vfield2d( "EMF/B", iter )
visxd.plot_vfield2d( "CURRENT/J", iter )
# Out:
# Plotting EMF/B in plane field for iteration 500.
# Plotting EMF/B out of plane field for iteration 500.
# Plotting CURRENT/J in plane field for iteration 500.
# Plotting CURRENT/J out of plane field for iteration 500.

# %% [markdown]
# ## LWFA test
#
# `lwfa_lwfa()`

# %%
import visxd

iter = 1229

visxd.plot_data("EMF/Ex", iter )
visxd.plot_data("EMF/Ey", iter )
visxd.plot_data("EMF/Ez", iter )

visxd.plot_data("CHARGE/electrons/electrons-charge", iter )
# Out:
# Plotting EMF/Ex-001229.zdf
# Plotting EMF/Ey-001229.zdf
# Plotting EMF/Ez-001229.zdf
# Plotting CHARGE/electrons/electrons-charge-001229.zdf
