# %% [markdown]
# # Visualizing ZDF files

# %%
import zdf

# zdf.list("test/test.zdf")
# zdf.list("test/test-000000.zdf")
zdf.list("EMF/Ex-000000.zdf")
# Out:
# Position     Size(bytes)  Type         Name
# -----------------------------------------------------
# 0x00000004   0x00000008   string       TYPE
# 0x00000020   0x000000a4   grid_info    Ex
# 0x000000d8   0x0000001c   iteration    Iteration
# 0x00000110   0x0000001c   cdset_start  Ex
# 0x00000140   0x00010034   cdset_chunk  00000001-chunk
# 0x00010194   0x00010034   cdset_chunk  00000001-chunk
# 0x000201e8   0x00010034   cdset_chunk  00000001-chunk
# 0x0003023c   0x00010034   cdset_chunk  00000001-chunk
# 0x00040290   0x00010034   cdset_chunk  00000001-chunk
# 0x000502e4   0x00010034   cdset_chunk  00000001-chunk
# 0x00060338   0x00010034   cdset_chunk  00000001-chunk
# 0x0007038c   0x00010034   cdset_chunk  00000001-chunk
# 0x000803e0   0x00010034   cdset_chunk  00000001-chunk
# 0x00090434   0x00010034   cdset_chunk  00000001-chunk
# 0x000a0488   0x00010034   cdset_chunk  00000001-chunk
# 0x000b04dc   0x00010034   cdset_chunk  00000001-chunk
# 0x000c0530   0x00010034   cdset_chunk  00000001-chunk
# 0x000d0584   0x00010034   cdset_chunk  00000001-chunk
# 0x000e05d8   0x00010034   cdset_chunk  00000001-chunk
# 0x000f062c   0x00010034   cdset_chunk  00000001-chunk
# 0x00100680   0x00000000   cdset_end    00000001-end

# %%
import visxd

visxd.grid( "test/test.zdf" )

# %%
import visxd

visxd.plot_data("test/test",0)
# Out:
# Plotting test/test-000000.zdf

# %%
import visxd

# visxd.plot_data("EMF/Ey",0)
visxd.plot_data("EMF/Ez",0)
visxd.plot_data("EMF/Ez",500)
visxd.plot_data("EMF/Ez",1000)
visxd.plot_data("EMF/Ez",1500)

#visxd.plot_data("EMF/By",100)
# Out:
# Plotting EMF/Ez-000000.zdf
# Plotting EMF/Ez-001500.zdf

# %%
import visxd

#visxd.plot_data("CHARGE/cathode/cathode-charge", 0)
#visxd.plot_data("PHASESPACE/cathode/cathode-xux", 0)
#visxd.plot_part("PARTICLES/cathode/particles-cathode", 0 )


for i in range(0,200,50):
#    visxd.plot_data("CHARGE/cathode/cathode-charge", i)
#    visxd.plot_part("PARTICLES/cathode/particles-cathode", i )
    visxd.plot_data("CURRENT/Jx", i )

# %%
import visxd

visxd.plot_data( "PHASESPACE/electrons/electrons-uxuz", 0 )
visxd.plot_data( "PHASESPACE/positrons/positrons-uxuz", 0 )

# %%
import visxd

# iter = 500
iter = 2143

visxd.plot_vfield2d("EMF/B", iter)

# %%
import visxd

visxd.plot_part("PARTICLES/electrons/particles-electrons", 500 )
