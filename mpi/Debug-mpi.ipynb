# %% [markdown]
# # Debug MPI code

# %% [markdown]
# ## test_grid

# %%
import zdf

# zdf.list("test/test.zdf")
# zdf.list("test/test-000000.zdf")
zdf.list("EMF/Ex-000000.zdf")

# %%
import visxd

visxd.grid( "test/test.zdf" )

# %%
import visxd

visxd.plot_data("test/test",0)
# Out:
# Plotting test/test-000000.zdf

# %% [markdown]
# ## test_laser

# %%
import visxd

# visxd.plot_data("EMF/Ey",0)
visxd.plot_data("EMF/Ez",0)
visxd.plot_data("EMF/Ez",500)
visxd.plot_data("EMF/Ez",1000)
visxd.plot_data("EMF/Ez",1500)

#visxd.plot_data("EMF/By",100)
# Out:
# Plotting EMF/Ez-000000.zdf
# Plotting EMF/Ez-000500.zdf
# Plotting EMF/Ez-001000.zdf
# Plotting EMF/Ez-001500.zdf

# %% [markdown]
# ## test_particles

# %%
# import zdf
import visxd

# zdf.list("PARTICLES/electrons/particles-electrons-000000.zdf")

# info = zdf.info("PARTICLES/electrons/particles-electrons-000000.zdf")
# print( info.particles )

visxd.plot_part("PARTICLES/electrons/particles-electrons", 0 )
visxd.plot_part("PARTICLES/electrons/particles-electrons", 0, qx = 'ux', qy = 'uy' )
visxd.plot_data("CHARGE/electrons/electrons-charge", 0)
# Out:
# Plotting PARTICLES/electrons/particles-electrons-000000.zdf
# Plotting PARTICLES/electrons/particles-electrons-000000.zdf

# %%
# visxd.plot_data("CHARGE/electrons/electrons-charge", 0, vmax = -0.98, vmin = -1.02 )

for i in range(0,110,10):
    # visxd.plot_part("PARTICLES/electrons/particles-electrons", i )
    visxd.plot_data("CHARGE/electrons/electrons-charge", i, vmax = -0.98, vmin = -1.02 )
# Out:
# Plotting CHARGE/electrons/electrons-charge-000000.zdf
# Plotting CHARGE/electrons/electrons-charge-000010.zdf
# Plotting CHARGE/electrons/electrons-charge-000020.zdf
# Plotting CHARGE/electrons/electrons-charge-000030.zdf
# Plotting CHARGE/electrons/electrons-charge-000040.zdf
# Plotting CHARGE/electrons/electrons-charge-000050.zdf
# Plotting CHARGE/electrons/electrons-charge-000060.zdf
# Plotting CHARGE/electrons/electrons-charge-000070.zdf
# Plotting CHARGE/electrons/electrons-charge-000080.zdf
# Plotting CHARGE/electrons/electrons-charge-000090.zdf
# Plotting CHARGE/electrons/electrons-charge-000100.zdf

# %%
for i in range(0,2):
    # visxd.plot_part("PARTICLES/electrons/particles-electrons", i )
    visxd.plot_data("CHARGE/electrons/electrons-charge", i, vmax = -0.98, vmin = -1.02)
    # visxd.plot_data("CHARGE/electrons/electrons-charge", i )

# %%
import visxd

#visxd.plot_data("CHARGE/cathode/cathode-charge", 0)
#visxd.plot_data("PHASESPACE/cathode/cathode-xux", 0)
#visxd.plot_part("PARTICLES/cathode/particles-cathode", 0 )


for i in range(0,200,50):
#    visxd.plot_data("CHARGE/cathode/cathode-charge", i)
#    visxd.plot_part("PARTICLES/cathode/particles-cathode", i )
    visxd.plot_data("CURRENT/Jx", i )

# %%
import visxd

visxd.plot_data( "PHASESPACE/electrons/electrons-uxuz", 0 )
visxd.plot_data( "PHASESPACE/positrons/positrons-uxuz", 0 )

# %% [markdown]
# ## Weibel Test

# %%
import visxd

iter = 500
# iter = 2143

visxd.plot_vfield2d("EMF/B", iter)
# Out:
# Plotting EMF/B in plane field for iteration 500.
# Plotting EMF/B out of plane field for iteration 500.

# %%
import visxd

visxd.plot_part("PARTICLES/electrons/particles-electrons", 500 )

# %% [markdown]
# ### Current deposit test

# %%
visxd.plot_data("CHARGE/electrons/electrons-charge", 0 )

for i in range(1,11):
    visxd.plot_data("CHARGE/electrons/electrons-charge", i )
    visxd.plot_vfield2d("CURRENT/J", i )


#for i in range(1,2):
#    visxd.plot_data("CHARGE/electrons/electrons-charge", i )
#    visxd.plot_data("CURRENT/Jx", i )
    # visxd.plot_data("CURRENT/Jy", i )
    # visxd.plot_data("CURRENT/Jz", i )
# Out:
# Plotting CHARGE/electrons/electrons-charge-000000.zdf
# Plotting CHARGE/electrons/electrons-charge-000001.zdf
# Plotting CURRENT/J in plane field for iteration 1.
# Plotting CURRENT/J out of plane field for iteration 1.
# Plotting CHARGE/electrons/electrons-charge-000002.zdf
# Plotting CURRENT/J in plane field for iteration 2.
# Plotting CURRENT/J out of plane field for iteration 2.
# Plotting CHARGE/electrons/electrons-charge-000003.zdf
# Plotting CURRENT/J in plane field for iteration 3.
# Plotting CURRENT/J out of plane field for iteration 3.
# Plotting CHARGE/electrons/electrons-charge-000004.zdf
# Plotting CURRENT/J in plane field for iteration 4.
# Plotting CURRENT/J out of plane field for iteration 4.
# Plotting CHARGE/electrons/electrons-charge-000005.zdf
# Plotting CURRENT/J in plane field for iteration 5.
# Plotting CURRENT/J out of plane field for iteration 5.
# Plotting CHARGE/electrons/electrons-charge-000006.zdf
# Plotting CURRENT/J in plane field for iteration 6.
# ...
